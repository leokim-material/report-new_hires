# %% [markdown]
# <a href="https://colab.research.google.com/github/leokim-material/report-new_hires/blob/main/Report_New_Hires.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Print list of new hires in following format:
# Name: Title | Company | Location
# Previously worked as TITLE at COMPANY. 
# PREFERRED NAME will be reporting to MANAGER.

from google.colab import files
import pandas as pd
import os
from termcolor import colored #format font color

# %%
#Setup files
directory = 'drive/MyDrive/Colab Notebooks/data/report-new hires/2021-Q3'
print(os.listdir(directory))

#Read files
df_offer_details = pd.read_excel(directory + '/' + 'offer_details_7july.xlsx', header=3)
df_candidates = pd.read_excel(directory + '/' + 'candidates_7july.xlsx')

#Merge (default inner so df_candidates will filter out for just july hires who accepted)
df_candidates['Candidate'] = df_candidates['First Name'] + ' ' + df_candidates['Last Name']
df_hired = df_offer_details.merge(df_candidates, left_on='Candidate', right_on='Candidate')#[['Candidate', 'Job']]

# print(df_hired.columns)
#Clean up
#Change to salary and sort descending

df_hired.head(1)
# Out:
# ['offer_details_7july.xlsx', 'candidates_7july.xlsx']
#          Candidate  Application ID_x  ... ADP Transfer Date  ADP File Number
# 0  Veronica Alcaro       91202262002  ...               NaN              NaN
#
# [1 rows x 88 columns]

# %%
count = 0
for candidate in range(df_hired.shape[0]):
  full_name = '\033[1m' + df_hired.loc[candidate,'Candidate'] + '\033[0m'
  job_title = df_hired.loc[candidate, 'Job']
  department = '\x1B[3m' + str(df_hired.loc[candidate, 'Department.1']) + '\x1B[0m'
  location = '\x1B[3m' + df_hired.loc[candidate, 'Location_x'] + '\x1B[0m'
  prev_job_title = str(df_hired.loc[candidate,'Title'])
  prev_company = colored(df_hired.loc[candidate,'Company'], 'blue')
  nickname = df_hired.loc[candidate,'Preferred Name']
  manager = df_hired.loc[candidate,'Manager']
  print(full_name + ': ' + job_title + ' | ' + department + ' | ' + location
        + '\n\tPreviously worked as ' + prev_job_title + ' at ' + prev_company + '.'  
        + '\n\t' + nickname + ' will be reporting to ' + manager + '.'
        + '\n'
        )
  count+=1

print(count)
# Out:
# Veronica Alcaro: Group Director, Brand | Salt | Remote
# 	Previously worked as nan at St. Michael's College.
# 	Veronica will be reporting to Jill Runyon.
#
# Jannel Alston: Marketing Manager | Group Marketing | Remote
# 	Previously worked as nan at nan.
# 	Jannel will be reporting to Max Branson.
#
# Hardik Amin: Director, Innovation & Strategy | Growth Strategy | Chicago
# 	Previously worked as nan at nan.
# 	Hardik will be reporting to Elizabeth Real.
#
# Camila Arana: Associate Program Manager | T3 | Remote
# 	Previously worked as nan at nan.
# 	Camila will be reporting to Stephanie Livieres.
#
# Joanna Asquith: Research Manager | Tonic | London
# 	Previously worked as nan at nan.
# 	Jo will be reporting to Jack Swanston.
#
# Jacqueline Benoit: Director, Compensation | Group HR | Remote
# 	Previously worked as nan at nan.
# 	Jackie will be reporting to Jamie Tiano.
#
# Kevin Bernal-Rivera: Research Associate  | Keever | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Kevin will be reporting to Michael Ohno.
#
# Petia Best: Assistant General Manager | LRWTonic | London
# 	Previously worked as Consultant, Dentsu Aegis at In this.
# 	Tia will be reporting to Krikor Mugerian.
#
# Robert Boggs: Workplace Experience Coordinator | Workplace Experience | Emeryville
# 	Previously worked as nan at nan.
# 	Robert will be reporting to Katie Cole.
#
# Briana Braudo: Senior Research Manager | Tonic | Remote
# 	Previously worked as nan at nan.
# 	Briana will be reporting to TBD.
#
# Joseph Bruggeman: Research Director | Keever | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Zack will be reporting to Bret Jonas.
#
# Jessica Burchett: Research Manager  | Tonic | Remote
# 	Previously worked as nan at nan.
# 	Jessica will be reporting to TBD.
#
# Joseph Bussard: Recruiting Researcher | Group HR | Remote
# 	Previously worked as nan at nan.
# 	Joseph Bussard will be reporting to Shayna Bullock.
#
# Dallas Capesius: Research Manager | Klubis | Remote
# 	Previously worked as nan at nan.
# 	Dallas will be reporting to Skylar Rainey.
#
# Michelle Chiles: Senior Strategist | T3 | Austin
# 	Previously worked as nan at nan.
# 	Michelle will be reporting to Keith Tanski.
#
# Tim Conley: Recruiting Coordinator | Group HR | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Tim Conley will be reporting to Anna Berk.
#
# Daisy Contreras: Research Associate | TIBU | Los Angeles 1800
# 	Previously worked as nan at nan.
# 	Daisy will be reporting to Suvra Mostafa.
#
# Raymonde Cook: Senior Research Manager | LRWTonic | London
# 	Previously worked as Senior Project Manager at Ipsos Mori.
# 	Ray will be reporting to Jenn Arrington-Korek.
#
# Beverly Crowson: Insights Director, Digital Analytics  | Digital Analytics | Remote
# 	Previously worked as nan at nan.
# 	Beverly Crowson will be reporting to Josh Verseput.
#
# Rick Davidson: Senior Accounts Payable Specialist | G&A: Admin - KEL | Los Angeles 1900
# 	Previously worked as AP Admin at CHOWNOW.
# 	Rick will be reporting to Mariana Amespil.
#
# Tiffany Deng: Market Research Intern | Cottrell | Remote
# 	Previously worked as nan at nan.
# 	Tiffany will be reporting to Sarah Hambro.
#
# Leonard Deschampe: Vice President, Digital Analytics | Digital Analytics | Los Angeles 1800
# 	Previously worked as nan at nan.
# 	Leonard Deschamp will be reporting to Josh Verseput.
#
# Kelsey Dickerson: Proofreader | T3 | Atlanta
# 	Previously worked as nan at nan.
# 	Kelsey will be reporting to Cynthia Houchin.
#
# Kevin Do: Research Associate  | Jagou | Orange County
# 	Previously worked as nan at nan.
# 	Kevin will be reporting to Paula Wotherspoon.
#
# Sean Donahue: Director, Loyalty + CRM | Loyalty & CRM - T3 | Austin
# 	Previously worked as nan at nan.
# 	Sean will be reporting to Sean Eidson.
#
# Amelia Draizin: Senior Recruiter | Group HR | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Amelia will be reporting to Alex Martin.
#
# Khoreen Eason: Recruiting Coordinator | Group HR | Remote
# 	Previously worked as nan at nan.
# 	Khoreen Eason will be reporting to Alex Martin.
#
# Elizabeth Elliott: Director, Enterprise Program Management Office | Executive | Remote
# 	Previously worked as Charity/ Events Chair at TransUnion.
# 	Liz will be reporting to Leena Patel.
#
# Morgan Farnsworth: Sr. Product Delivery Manager | T3 | Austin
# 	Previously worked as Sr. Digital Producer at MCGARRAH JESSEE.
# 	Morgan will be reporting to Amber Jones.
#
# Eric Feliz: Global Data Collection Associate  | Global Data Collection | Remote
# 	Previously worked as nan at nan.
# 	Eric will be reporting to TBD.
#
# Emilie Fleck: Research Associate | TIBU | Los Angeles 1800
# 	Previously worked as nan at nan.
# 	Emilie will be reporting to Venessa Scott.
#
# Jordan Gates: Senior Analyst | T3 | Austin
# 	Previously worked as nan at nan.
# 	Jordan Gates will be reporting to Christopher Macauley.
#
# Marielle Geerling: Intern, Account Management | Karma Agency | Remote
# 	Previously worked as nan at nan.
# 	Marielle will be reporting to tbd.
#
# Kyle Goldfarb: Connections Intern | T3 | Austin
# 	Previously worked as nan at nan.
# 	Kyle will be reporting to Candice Garcia.
#
# Johanan Gomez: Manager, Helpdesk | Group IT - Digital Workplace | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Johanan will be reporting to Glen Durmas.
#
# Shontel Gray: Business Relationship Manager, Talent | Material | Remote
# 	Previously worked as nan at nan.
# 	Shontel will be reporting to Wael Amer.
#
# Cole Greenberg: Research Manager | Klubis | Remote
# 	Previously worked as nan at nan.
# 	Cole will be reporting to Julia Park.
#
# Gregory Grzywacz: Research Director | Parsons | Remote
# 	Previously worked as nan at nan.
# 	Greg will be reporting to Matthew Parsons.
#
# Sara Hall: Resource Operations Manager | T3 | Remote
# 	Previously worked as nan at nan.
# 	Sara will be reporting to Jennifer Zuck.
#
# Diane Harris: Accounts Payable Specialist | Finance - T3 | Austin
# 	Previously worked as nan at nan.
# 	Diane will be reporting to Robert Hurley.
#
# Laura Hay: Senior Research Manager  | TIBU | Remote
# 	Previously worked as nan at nan.
# 	Laura will be reporting to TBD.
#
# Jose Herrera: Staff Accountant | Finance | Los Angeles 1800
# 	Previously worked as nan at nan.
# 	Jose will be reporting to Hao Sun.
#
# Alisha Herrick: Learning and Development Manager | Group HR | Remote
# 	Previously worked as nan at nan.
# 	Alisha Herrick will be reporting to Mong Sai.
#
# Tabitha Hoover: Communications Coordinator | T3 | Remote
# 	Previously worked as Community Assistant at nan.
# 	Tabitha will be reporting to Emma Coker.
#
# Chris Hosmer: Managing Director, Product Design | T3 | Remote
# 	Previously worked as nan at nan.
# 	Chris will be reporting to Allyson Meyer.
#
# Ali Husain: Research Associate | Li | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Ali will be reporting to Apoorva Kelkar.
#
# Stephen Imamura: CRM Operations Manager | T3 | Remote
# 	Previously worked as nan at nan.
# 	Stephen will be reporting to Eva Huang.
#
# Jade Jackson: Senior Manager, CX Consulting | Strativity | Remote
# 	Previously worked as nan at nan.
# 	Jade will be reporting to Pernell Cox.
#
# Stephen Jacobs: Senior Software Engineer | Software Engineering | Los Angeles 1900
# 	Previously worked as Integrations Developer at Scorpion Internet Marketing.
# 	Stephen will be reporting to Saad Houri.
#
# Amena Jannat: Research Associate  | Jagou | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Amena will be reporting to Renata Filler.
#
# Robert Kazmi: Associate Director, Insights & Strategy (Quantitative) | Kelton | Remote
# 	Previously worked as nan at nan.
# 	Robert will be reporting to Steven Kovacs.
#
# Connor Kennedy: Sr. Paid Search Specialist | Connections - T3 | Austin
# 	Previously worked as nan at nan.
# 	Connor will be reporting to Jordann Wilson.
#
# Stacie Kern: Field Manager | Client Services: Qual - KEL | Chicago
# 	Previously worked as SENIOR PROJECT MANAGER at Egg Strategy.
# 	Stacie will be reporting to Sunetra Banerjee.
#
# Sandhya Keshavabhotla: Designer | Design | Remote
# 	Previously worked as nan at nan.
# 	Sandhya will be reporting to Marcus Lee.
#
# Christ Khodabakhshi: Senior Software Engineer | Software Engineering | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Christ will be reporting to Brad Bazley.
#
# Jared Kline: Data Scientist | Marketing Science | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Jared will be reporting to Tyler Solloway.
#
# Cailin Knox: Associate Director, Client Development | Kelton | Remote
# 	Previously worked as nan at nan.
# 	Cailin will be reporting to Joey Doney.
#
# Katie Lee: Associate Survey Engineer | IPS | Remote
# 	Previously worked as nan at nan.
# 	Katie will be reporting to Kayla Elias.
#
# Stephen Loeffler: Director, Loyalty + CRM | T3 | Remote
# 	Previously worked as nan at nan.
# 	Stephen will be reporting to Sean Eidson.
#
# Nick Lowry: Senior Account Executive  | Karma Agency | Remote
# 	Previously worked as nan at nan.
# 	Nick will be reporting to Cat McQuail.
#
# Cindy Lu: Global Data Collection Associate  | Global Data Collection | Remote
# 	Previously worked as nan at nan.
# 	Cindy will be reporting to Michael Frontino.
#
# Rudy Macias: Developer | T3 | Austin
# 	Previously worked as nan at nan.
# 	Rudy will be reporting to Pat Starr.
#
# Lauren Markaverich: Media Director | Connections - T3 | Austin
# 	Previously worked as Tuesday Morning at McGarrah Jessee Frost Bank.
# 	Lauren will be reporting to James Lanyon.
#
# Eric Mathis: VP, Growth Strategy | Kelton | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Eric will be reporting to Amy Rogoff Dunn.
#
# Caitlin McNally: Program Manager | T3 | Austin
# 	Previously worked as nan at nan.
# 	Caitlin will be reporting to Liz Matijasic.
#
# Sarah Medeiros: Associate Talent Business Partner | Group HR | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Sarah will be reporting to Kelli Serden.
#
# Maritza Melendez: Senior Director, Enterprise Program Management Office | Executive | Remote
# 	Previously worked as HR DIRECTOR, US PEOPLE & CULTURE at Andela Inc..
# 	Maritza will be reporting to Leena Patel.
#
# Matt Milburn: Research Associate  | Valenzuela | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Matt will be reporting to TBD.
#
# Taneil Mindham: Operations Coordinator | T3 | Austin
# 	Previously worked as nan at nan.
# 	Taneil will be reporting to Meredith Crumley.
#
# Mason Miranda: PR Account Executive | Employees - KAR | Remote
# 	Previously worked as nan at nan.
# 	Mason will be reporting to Cat McQuail.
#
# Jessica Montgomery: Research Director | TIBU | Los Angeles 1800
# 	Previously worked as Research Analyst at 451 Research (a part of S&P Global Market Intelligence.
# 	Jessica will be reporting to Emma Angelica.
#
# Kyle Murphy: Global Data Collection Associate  | Global Data Collection | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Kyle will be reporting to Alexa Dobrowski.
#
# Eli Nasser: Research Director | TIBU | Los Angeles 1800
# 	Previously worked as nan at nan.
# 	Eli will be reporting to TBD.
#
# Reed Neulight: Market Research Intern | Shrut | Remote
# 	Previously worked as nan at nan.
# 	Reed will be reporting to Mira Metry.
#
# Cindy Ng: Content Marketing Manager | Group Marketing | Remote
# 	Previously worked as nan at nan.
# 	Cindy will be reporting to Max Bronson.
#
# Annie Norbitz: Senior Director, Qualitative Research | Kelton | Kelton NYC
# 	Previously worked as nan at nan.
# 	Annie will be reporting to Amy Rogoff Dunn.
#
# Michael O'Grady: VP, Insights & Strategy (Quantitative) | Client Services: KQS - KEL | Remote
# 	Previously worked as nan at nan.
# 	Mick will be reporting to Amy Dunn.
#
# Hannah O'Keefe: Research Manager  | Keever | Remote
# 	Previously worked as nan at nan.
# 	Hannah will be reporting to Julia Garcia.
#
# Brooke Ostendorf: VP of New Business | Growth - T3 | Remote
# 	Previously worked as Director, Strategic Growth at Isobar (and dentsu creative).
# 	Brooke will be reporting to Joey Doney.
#
# Jamie Park: Creative Director | Karma Agency | Philadelphia
# 	Previously worked as nan at nan.
# 	Jamie Park will be reporting to Tracy Thompson.
#
# Kelsey Parker-Montagnini: Research Associate  | Jagou | Remote
# 	Previously worked as nan at nan.
# 	Kelsey will be reporting to Renata Filler.
#
# Melissa Parkerson: Workplace Experience Coordinator | Workplace Experience | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Melissa will be reporting to Jason Redondo.
#
# Leena Patel: VP, Enterprise Program Management Office | Group Executive | Remote
# 	Previously worked as nan at nan.
# 	Leena will be reporting to Anthony Laria.
#
# Dana Phelps: Associate Director, Design Research | T3 | Remote
# 	Previously worked as nan at nan.
# 	Dana will be reporting to Allyson Meyer.
#
# Lugdivine Pironi: Research Director | LRWTonic | London
# 	Previously worked as nan at nan.
# 	Lugdivine will be reporting to Tia Best.
#
# Kathy Profio Norris: Group Account Director, Loyalty + CRM | T3 | Austin
# 	Previously worked as nan at nan.
# 	Kathy Profio Norris will be reporting to Sean Eidson.
#
# Meredith Pursell: Director, Growth Strategy | T3 | Remote
# 	Previously worked as nan at nan.
# 	Meredith will be reporting to Joey Doney.
#
# Anna Raghavan: Senior Recruiter | Group HR | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Anna will be reporting to Alex Martin.
#
# Richard Reilly: Principal, Consulting | Strativity | Remote
# 	Previously worked as nan at nan.
# 	Rick will be reporting to Wayne Morris.
#
# Tyler Reinke: Senior Research Manager | Klubis | Remote
# 	Previously worked as nan at nan.
# 	Tyler will be reporting to Mariel (Grubbs) Duffett.
#
# Cynthia Rekar: Research Report Writer | Greenberg | San Francisco
# 	Previously worked as nan at nan.
# 	Cynthia will be reporting to Allison Wilt.
#
# Isobel Riant: Research Associate  | Cottrell | New York
# 	Previously worked as nan at nan.
# 	Isobel will be reporting to Alex Cervantes.
#
# Zachary Richardson: Associate Director, Insights & Strategy (Quantitative) | Client Services: KQS - KEL | Remote
# 	Previously worked as Senior Consultant, Strategy Division at Kantar.
# 	Zachary will be reporting to Bryce Quayle.
#
# Katrina Rivera: Intern, Market Research | Kelton | Remote
# 	Previously worked as nan at nan.
# 	Katrina will be reporting to Collin Wood.
#
# Sydney Rodriguez: Social Coordinator | Connections - T3 | Remote
# 	Previously worked as nan at nan.
# 	Sydney will be reporting to Candice Garcia.
#
# Kristina Salway: Account Manager | Stone | Chicago
# 	Previously worked as Director, Consumer & Brand Insights at Subway.
# 	Kristy will be reporting to Jeffrey Stone.
#
# Sofia Samee: Research Associate  | Cottrell | New York
# 	Previously worked as nan at nan.
# 	Sofia will be reporting to Agnes Wasilewski.
#
# Angad Sandhu: Senior Loyalty Strategist | Loyalty & CRM - T3 | Remote
# 	Previously worked as nan at nan.
# 	Angad will be reporting to Sean Eidson.
#
# Shay Santos: Research Associate | TIBU | Los Angeles 1800
# 	Previously worked as nan at nan.
# 	Shay will be reporting to Natalie Montes.
#
# Lee Saunders: Senior Director, Insights & Strategy | Kelton | Kelton NYC
# 	Previously worked as Senior Director, Insights & Strategy at Kelton Global.
# 	Lee will be reporting to Jaclyn Brannon.
#
# Vivien Schweitzer: Copywriter | Group Marketing | Remote
# 	Previously worked as nan at nan.
# 	Vivien will be reporting to Max Branson.
#
# Salonee Seecharan: Research Associate  | Cottrell | Chicago
# 	Previously worked as nan at nan.
# 	Salonee will be reporting to TBD.
#
# Kaitlin Shaffer: Research Manager | Li | Los Angeles 1800
# 	Previously worked as nan at nan.
# 	Kaitlin will be reporting to Apoorva Kelkar.
#
# Mark Shanahan: Principal Recruiter | Group HR | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Mark will be reporting to Anna Berk.
#
# Sachi Shirali: Research Associate  | Gormley | Remote
# 	Previously worked as nan at nan.
# 	Sachi will be reporting to Lindsey Wagner.
#
# Suzanna Sim: Quantitative Junior Program Manager | Greenberg | San Francisco
# 	Previously worked as nan at nan.
# 	Suzanna will be reporting to Miriam Nelson.
#
# Kara Sisenstein: Senior Analyst, Quantitative | Client Services: KQS - KEL | New York
# 	Previously worked as nan at nan.
# 	Kara will be reporting to Matt Paladino.
#
# Tiffany Soohoo: Senior Product Designer | T3 | Remote
# 	Previously worked as nan at nan.
# 	Tiffany will be reporting to Allyson Meyer.
#
# Daisy Soria: Research Associate  | Keever | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Daisy will be reporting to Jessica Dombrowski.
#
# Warren Starks: Global Data Collection Associate  | Global Data Collection | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Warren will be reporting to Hillary Stabelfeldt.
#
# Nolan Talavou: Research Associate  | Rory | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Nolan will be reporting to James DeSimas.
#
# Oliver Tate: Senior Analyst, Quantitative | Kelton | Remote
# 	Previously worked as nan at nan.
# 	Oliver will be reporting to Cameron Gonzalez.
#
# Zachary Taylor: Designer | Design | Remote
# 	Previously worked as nan at nan.
# 	Zachary will be reporting to John Wuchte.
#
# Test Test: Analyst, Qualitative Research | Kelton | Kelton NYC
# 	Previously worked as nan at nan.
# 	Test will be reporting to Shawnna Kenner.
#
# Trina Tran: Research Associate  | Jagou | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Trina will be reporting to Tom Dianora.
#
# Tsvetelin Tsonevski: Business Relationship Manager, CRM | Group IT - Business Applications | Los Angeles 1900
# 	Previously worked as Manager of Sales Operations at HR for Health.
# 	Tsvet will be reporting to Wael Amer.
#
# Laurie Visee: VP, Assistant General Manager | Stone | Chicago
# 	Previously worked as nan at nan.
# 	Laurie will be reporting to Jonathan Weiss.
#
# Lindsay Voss: Research Associate  | Rory | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Lindsay will be reporting to TBD.
#
# Julie Warriner: Director, Insights & Strategy (Quantitative) | Client Services: KQS - KEL | Remote
# 	Previously worked as nan at nan.
# 	Julie will be reporting to Matt Drab.
#
# Erin Weinland: VP | Client Services: KQS - KEL | Remote
# 	Previously worked as Founder & Chief Insights at WEAVE INSIGHTS LLC.
# 	Erin will be reporting to Matt Paladino.
#
# Jessica Willard: Art Director | T3 | Austin
# 	Previously worked as nan at nan.
# 	Jessica will be reporting to Bonnie Rohan.
#
# Bianca Williams: Connections Intern | T3 | Austin
# 	Previously worked as nan at Systems Inc..
# 	Bianca will be reporting to Kendall Schultz.
#
# Chase Williams: Director, Product Delivery | T3 | Austin
# 	Previously worked as nan at nan.
# 	Chase Williams will be reporting to Mark Price.
#
# Kayla WILLIS-CHAMBERS: Account Executive  | Karma Agency | Remote
# 	Previously worked as nan at nan.
# 	Kayla will be reporting to Kyle Yamamoto.
#
# Anna Wilson: Senior Analyst, Quantitative | Kelton | Remote
# 	Previously worked as nan at nan.
# 	Anna will be reporting to TBD.
#
# Jiali Wu: Research Associate | TIBU | Remote
# 	Previously worked as nan at nan.
# 	Jolie will be reporting to Ben Abrams.
#
# Izgi Yavuz Tapia: Designer | Design | Los Angeles 1800
# 	Previously worked as nan at nan.
# 	Izgi will be reporting to Marcus Lee.
#
# David Yehaskel: Director of SEO | T3 | Austin
# 	Previously worked as nan at nan.
# 	David will be reporting to Allyson Meyer.
#
# Steve Yoon: Associate Director, Product Design | Product Design - T3 | Austin
# 	Previously worked as Design Lead at USAA.
# 	Steve will be reporting to Allyson Meyer.
#
# Leon Zhu: Research Manager  | Jagou | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Leon will be reporting to Tyler Christopherson Schorn.
#
# 130
