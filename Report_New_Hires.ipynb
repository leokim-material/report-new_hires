# %% [markdown]
# <a href="https://colab.research.google.com/github/leokim-material/report-new_hires/blob/main/Report_New_Hires.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Print list of new hires in following format:
# Name: Title | Company | Location
# Previously worked as TITLE at COMPANY. 
# PREFERRED NAME will be reporting to MANAGER.

from google.colab import files
import pandas as pd
import os
from termcolor import colored #format font color
import numpy as np

# %%
#Setup files
directory = 'drive/MyDrive/Colab Notebooks/Report-New Hires/data/2021-Q3'

#Read files
df_offer_details = pd.read_excel(directory + '/' + 'offer_details_2021Q3.xlsx', header=3)
df_candidates = pd.read_excel(directory + '/' + 'candidates_2021Q3.xlsx')
#Add column for first+last name
df_candidates['Candidate'] = df_candidates['First Name'] + ' ' + df_candidates['Last Name']

#Merge (default inner so df_candidates will filter out for just hires who accepted within the month(s) in df_candidates)
#List of columns to keep
keep_columns = ['Candidate', 'Job', 'Preferred Name', 'Location_x', 'Department.1', 'Manager', 'Employment Type', 
                'Rate Type', 'Pay Rate', 'Title', 'Company', 'Location_y', 'Education1']
df_hired = df_offer_details.merge(df_candidates, left_on='Candidate', right_on='Candidate')#[keep_columns]

#Clean up------------------------------------------------------

#Filter for FTE
df_hired = df_hired.loc[df_hired['Employment Type'] == 'Full-time'].reset_index(drop=True)

#Pay Rate: remove currency symbols & convert hourly rate to annualized salary
df_hired['Pay Rate'] = df_hired['Pay Rate'].str.replace('[$€,]', '').astype('float')
print('Pay Rate dtype correctly converted?', df_hired['Pay Rate'].dtypes)
#np.where(condition, result if condition met, result if not met)
df_hired['Pay Rate'] = np.where(df_hired['Rate Type'] == 'Hourly- Full Time', df_hired['Pay Rate'] * 2080, df_hired['Pay Rate'])
df_hired = df_hired.sort_values(['Pay Rate', 'Job'], ascending=False).reset_index(drop=True)
#---------------------------------------------------------------

#Check repeat names
df_hired['Candidate'].value_counts()[df_hired['Candidate'].value_counts() > 1]
# Out:
# Pay Rate dtype correctly converted? float64
# Series([], Name: Candidate, dtype: int64)

# %%
#notes
#Eric Feliz - manager=Kayla Takemoto
#Received an M.S. in Management from University of Notre Dame

#Sandhya Keshavabhotla - prev worked through Upwork
#Lee Saunders - rehired
#Anna Wilson - Received a BSBA with emphasis in Marketing from University of Colorado
#Anna will be reporting to Laura Majonnier.

#Izgi Yavuz Tapia - freelancer no comapny
#Raymonde Cook - freelancer FOR Blux
#change all senior to Sr. for job title & prev job title
#
#hohjin im - received phd

#AUGUST
#remove 'material newhireone two'

#SEPTEMBER
#checked 9/1-9/19

# %%
#Number of new hires
count = df_hired.shape[0]
print(str(count) + ' FTE', '\n')

for candidate in range(df_hired.shape[0]):
  #Grab variables
  full_name = '\033[1m' + df_hired.loc[candidate, 'Candidate'] + '\033[0m'
  job_title = df_hired.loc[candidate, 'Job']
  department = '\x1B[3m' + str(df_hired.loc[candidate, 'Department.1']) + '\x1B[0m'
  location = '\x1B[3m' + df_hired.loc[candidate, 'Location_x'] + '\x1B[0m'
  prev_job_title = str(df_hired.loc[candidate,'Title'])
  prev_company = colored(df_hired.loc[candidate,'Company'], 'blue')
  nickname = df_hired.loc[candidate,'Preferred Name']
  manager = df_hired.loc[candidate,'Manager']

  print(full_name + ': ' + job_title + ' | ' + department + ' | ' + location
        + '\n\tPreviously worked as ' + prev_job_title + ' at ' + prev_company + '.'  
        + '\n\t' + nickname + ' will be reporting to ' + manager + '.'
        + '\n'
        )
# Out:
# 120 FTE
#
# Natasha Stevens: SVP, Tracking Business Development & Retention | TIBU | New York
# 	Previously worked as Executive Vice President - Strategy and Product Innovation at GfK.
# 	Natasha will be reporting to Eric Asch.
#
# Todd Oliverio: VP, Enterprise Program Management Office | Group Executive | Remote
# 	Previously worked as Sr. Program Manager at PwC.
# 	Todd will be reporting to Leena Patel.
#
# Brooke Ostendorf: VP of New Business | Growth - T3 | Remote
# 	Previously worked as Director, Strategic Growth at Isobar.
# 	Brooke will be reporting to Joey Doney.
#
# Maritza Melendez: Senior Director, Enterprise Program Management Office | Executive | Remote
# 	Previously worked as HR Director, US People & Culture at Andela Inc.
# 	Maritza will be reporting to Leena Patel.
#
# Lee Saunders: Senior Director, Insights & Strategy | Kelton | Kelton NYC
# 	Previously worked as Senior Director, Insights & Strategy at Kelton Global.
# 	Lee will be reporting to Jaclyn Brannon.
#
# Sarah Cherrabi El Alaoui: Senior Director, Qualitative Research | Client Services: Qual - KEL | Remote
# 	Previously worked as Research Director at Brain Value.
# 	Sarah will be reporting to Jaclyn Jakucki.
#
# Elizabeth Elliott: Director, Enterprise Program Management Office | Executive | Remote
# 	Previously worked as Charity/ Events Chair at TransUnion.
# 	Liz will be reporting to Leena Patel.
#
# Simon Azim: Director, Analytics | Intelligence - T3 | Remote
# 	Previously worked as Senior Director, Decision Science & Data Governance at Le-Vel Brands/Specture Labs.
# 	Simon Azim will be reporting to Christopher Macauley.
#
# Tiffany Francis: Group Director, PR & Communications | Employees - KAR | Philadelphia
# 	Previously worked as Director, Marketing Communications at Q2.
# 	Tiffany will be reporting to Caroline Kennedy.
#
# Amelia Ellsworth: VP, Insights & Strategy (Quantitative) | Client Services: KQS - KEL | Remote
# 	Previously worked as Research Director at Shine United.
# 	Amelia will be reporting to Matt Paladino.
#
# Sean Donahue: Director, Loyalty + CRM | Loyalty & CRM - T3 | Austin
# 	Previously worked as Director of Marketing, Technical Services at Tinuiti.
# 	Sean will be reporting to Sean Eidson.
#
# Lauren Markaverich: Media Director | Connections - T3 | Austin
# 	Previously worked as Media Director at McGarrah Jessee.
# 	Lauren will be reporting to James Lanyon.
#
# Jade Jackson: Senior Manager, CX Consulting | Strativity | Remote
# 	Previously worked as Customer Experience Manager at McMaster-Carr.
# 	Jade will be reporting to Pernell Cox.
#
# Lindsay Brown: Media Director | Connections - T3 | Austin
# 	Previously worked as Director at Spark Foundry.
# 	Lindsay will be reporting to James Lanyon.
#
# Anne Ramsburg: Group Account Director | Account Management - T3 | Austin
# 	Previously worked as Collaboration Director at The Butler Bros.
# 	Anne will be reporting to Jill Runyon.
#
# Chase Williams: Director, Product Delivery | T3 | Austin
# 	Previously worked as Product Manager at Temenos.
# 	Chase Williams will be reporting to Mark Price.
#
# Tegen Oakman: Research Director | Gormley | Remote
# 	Previously worked as Consumer Insights Sr. Manager at Polaris, Inc.
# 	Tegen will be reporting to Lindsey Wagner.
#
# Steve Yoon: Associate Director, Product Design | Product Design - T3 | Austin
# 	Previously worked as Design Lead at USAA.
# 	Steve will be reporting to Allyson Meyer.
#
# Robert SantAnselmo: Insights Director, Digital Analytics | Digital Analytics | Los Angeles 1900
# 	Previously worked as EVP, Global Digital Insights & Brand Strategy at Digital Hug.
# 	Robert SantAnselmo will be reporting to Janine (Harispe) Arai.
#
# Jonathan Beazley: Senior Manager, Marketing and Data Science | Marketing Science | Remote
# 	Previously worked as Marketing Scientist/Consultant at nan.
# 	Jon will be reporting to Rosy Garcia-Rivas.
#
# Kathy Profio Norris: Group Account Director, Loyalty + CRM | T3 | Austin
# 	Previously worked as Sr. Account Director at Augustine Agency.
# 	Kathy Profio Norris will be reporting to Sean Eidson.
#
# Johanan Gomez: Manager, Helpdesk | Group IT - Digital Workplace | Los Angeles 1900
# 	Previously worked as Senior Service Desk Analyst - Service Desk Lead at CIM Group.
# 	Johanan will be reporting to Glen Durmas.
#
# Tsvetelin Tsonevski: Business Relationship Manager, CRM | Group IT - Business Applications | Los Angeles 1900
# 	Previously worked as Manager of Sales Operations at HR for Health.
# 	Tsvet will be reporting to Wael Amer.
#
# Morgan Farnsworth: Sr. Product Delivery Manager | T3 | Austin
# 	Previously worked as Sr. Digital Producer at MCGARRAH JESSEE.
# 	Morgan will be reporting to Amber Jones.
#
# Ryan Woodman: Senior Strategist, Gaming & Entertainment | Titanium - GB | Remote
# 	Previously worked as Senior Manager at Morning Consult.
# 	Ryan will be reporting to Jenessa Hunter.
#
# Stephen Jacobs: Senior Software Engineer | Software Engineering | Los Angeles 1900
# 	Previously worked as Integrations Developer at Scorpion Internet Marketing.
# 	Stephen will be reporting to Saad Houri.
#
# Senjo Hermiz Gabriel: Research Director | Cottrell | Chicago
# 	Previously worked as Marketing Insights Manager, Research & Customer Insights at Coyote Logistics.
# 	Sam will be reporting to Madeleine Chansky.
#
# Alison Hitzker: Research Director | TIBU | Remote
# 	Previously worked as Marketing Research Director & Generation Ipsos Service Line Coordinator at Ipsos.
# 	Alison will be reporting to Christine Sathre.
#
# Julie Warriner: Director, Insights & Strategy (Quantitative) | Client Services: KQS - KEL | Remote
# 	Previously worked as Director, Product Research & Dedicated Solutions at MRI-Simmons.
# 	Julie will be reporting to Matt Drab.
#
# Bianca Di Salvo: Senior Qualitative Director | Element Y - GB | Remote
# 	Previously worked as Marketing Research Consultant at various companies.
# 	Bianca will be reporting to Allison Wilt.
#
# Ana Alvarez Suárez: Machine Learning Engineer | Marketing Science | Los Angeles 1900
# 	Previously worked as Junior Machine Learning and Computer Vision Engineer at MoviTHERM/MoviMED.
# 	Ana will be reporting to Hrag Balian.
#
# Thomas VandenBoom: Data Scientist | Marketing Science | Los Angeles 1900
# 	Previously worked as J. Willard Gibbs Assistant Professor in Mathematics at Yale University.
# 	Tom will be reporting to Tyler Solloway.
#
# Zachary Richardson: Associate Director, Insights & Strategy (Quantitative) | Client Services: KQS - KEL | Remote
# 	Previously worked as Senior Consultant, Strategy Division at Kantar.
# 	Zachary will be reporting to Bryce Quayle.
#
# Kara Schwenkmeyer: Senior Consultant, CX Consulting | Strativity | Remote
# 	Previously worked as Senior Associate at Grant Thornton LLP.
# 	Kara Schwenkmeyer will be reporting to Ali Nigh.
#
# Danielle Naselli: Senior Strategist - Performance Marketing | Strategy & Innovation - T3 | Austin
# 	Previously worked as Associate Director at Dentsu Aegis iProspect.
# 	Danielle will be reporting to Glenn Geller.
#
# Alicia Jenkins: Senior Research Manager | TIBU | Remote
# 	Previously worked as Senior Research Specialist at Kantar Profiles.
# 	Alicia will be reporting to Anu Rawlins.
#
# Dominique DiCamillo: Application Administrator, Talent | Group IT - Business Applications | Remote
# 	Previously worked as HRIS Manager at Global Brands Group.
# 	Dominique will be reporting to Shontel Gray.
#
# Gretchen Gudites: Associate Director, Insights & Strategy (Quantitative) | Client Services: KQS - KEL | Remote
# 	Previously worked as Global Field Director and Facilitator at FUEL Global.
# 	Gretchen will be reporting to Chelsea Schafer.
#
# Evan Cox: Senior Research Manager | Gormley | Remote
# 	Previously worked as Consumer Insights Manager at Vive Organic.
# 	Evan will be reporting to Robyn Rosen.
#
# Jessica Montgomery: Research Director | TIBU | Los Angeles 1800
# 	Previously worked as Research Analyst at 451 Research.
# 	Jessica will be reporting to Emma Angelica.
#
# Stacie Kern: Field Manager | Client Services: Qual - KEL | Chicago
# 	Previously worked as Sr. Project Manager at Egg Strategy.
# 	Stacie will be reporting to Sunetra Banerjee.
#
# Natalie Holcomb: Associate Program Director | Brand Delivery - T3 | Austin
# 	Previously worked as Account Manager at L&E International.
# 	Natalie will be reporting to Allyson Mays.
#
# Sunaina Luthra: Senior Research Manager | Keever | Remote
# 	Previously worked as Sr. Manager, Insights at Course5i.
# 	Sunaina will be reporting to Michael Ohno.
#
# Sara Feinberg: Associate Director, Insights & Strategy (Quantitative) | Client Services: KQS - KEL | Remote
# 	Previously worked as Account Manager at Ipsos.
# 	Sara will be reporting to Katherine Moran.
#
# Garrett Ringler: Senior Analyst | Intelligence - T3 | Remote
# 	Previously worked as Data Strategist at Liquid + Arcade.
# 	Garrett Ringler will be reporting to Christopher Macauley.
#
# Lauren Smith: Marketing Data Analyst | Intelligence - T3 | Remote
# 	Previously worked as Data Strategist at Liquid+Arcade.
# 	Lauren Smith will be reporting to Christopher Macauley.
#
# John Swanson: Junior Data Engineer | Marketing Science | Remote
# 	Previously worked as Data Analyst, Data Engineer at Government Finance Research Group.
# 	John will be reporting to Nathaniel Payumo.
#
# Hohjin Im: Senior Marketing Science Analyst | Marketing Science | Remote
# 	Previously worked as Ph.D. Candidate at University of California, Irvine.
# 	Hohjin will be reporting to Alina Ostrander.
#
# Raymond Law: Senior Research Manager | TIBU | Los Angeles 1800
# 	Previously worked as Strategic Director at Kantar.
# 	Raymond will be reporting to Brandon Florio.
#
# Samuel DePagter: Senior Research Manager | TIBU | Remote
# 	Previously worked as Account Manager at Ipsos.
# 	Sam will be reporting to Eunice Chun.
#
# Roya Latifi: Senior Marketing Science Analyst | Marketing Science | Los Angeles 1900
# 	Previously worked as nan at nan.
# 	Roya will be reporting to TBD.
#
# Brianna Deveraux: Senior Loyalty Strategist | Loyalty & CRM - T3 | Remote
# 	Previously worked as Digital Marketing Manager at Ikes Love & Sandwiches.
# 	Brianna will be reporting to Sean Eidson.
#
# Caroline Hisey: Senior Research Manager | Valenzuela | Remote
# 	Previously worked as Shopper Insights Analyst at Kantar.
# 	Caroline will be reporting to Michelle Helving.
#
# Henri Georges Anguillet Roumeliotis: Senior Financial Analyst | Group Finance | Los Angeles 1900
# 	Previously worked as Financial Analyst II at The Village Family Services.
# 	Henri will be reporting to Karin Brummell.
#
# Stephen Pino: Senior Research Manager | Valenzuela | Remote
# 	Previously worked as Market Research Manager at Ipsos.
# 	Stephen will be reporting to TBD.
#
# Rachel Knowles: Content Marketing Manager | Group Marketing | Remote
# 	Previously worked as Communications Specialist at Flavorman & Moonshine University.
# 	Rachel will be reporting to Max Branson.
#
# Erika Ramberg: Associate Director Business Development | Accounts - KVS | Seattle
# 	Previously worked as Business Development Manager at Substantial.
# 	Erika Ramberg will be reporting to Grant Landram.
#
# Robert Jewell: Recruiter | Group HR | Los Angeles 1900
# 	Previously worked as Recruiter at ViacomCBS.
# 	Robert will be reporting to Anna Berk.
#
# Jannel Alston: Marketing Manager | Group Marketing | Remote
# 	Previously worked as Sr. Customer Development Analyst at Johnson & Johnson.
# 	Jannel will be reporting to Max Branson.
#
# Will Silberman: Strategist, Social Analytics | MQ - Strategy | Chicago
# 	Previously worked as Dorothy M. Carozza Cancer Communication Research Fellow at University of Kentucky.
# 	Will will be reporting to Joy Boggio.
#
# Rachel Bondurant: Senior Copywriter | Content - KVS | Remote
# 	Previously worked as Communications Coordinator at Gutterglove, Inc.
# 	Rachel will be reporting to Josh Miles.
#
# Olivia Wenzel: Sr. Paid Search Specialist | Connections - T3 | Remote
# 	Previously worked as Digital Marketing Specialist at CloudCommerce.
# 	Olivia will be reporting to Jordann Wilson.
#
# Claudia Powell: Senior Project Manager, Qualitative Research | Project Management - ISA | Sherman Oaks
# 	Previously worked as Marketing Research Field Supervisor at NBCUniversal Media - Universal Studios Hollywood.
# 	Claudia will be reporting to Linda Giniewica.
#
# Rick Davidson: Accounts Payable Specialist | G&A: Admin - KEL | Los Angeles 1900
# 	Previously worked as AP Admin at ChowNow.
# 	Rick will be reporting to Mariana Amespil.
#
# Melanie Shell: Senior Associate, Client Development | Sales - KEL | Los Angeles 1900
# 	Previously worked as Key Account Manager at Segafredo Zanetti.
# 	Melanie will be reporting to Jane Bender.
#
# Carla Ibarra: Research Manager | LRWTonic | Remote
# 	Previously worked as Research Analyst & Customer Success at Worthix Inc.
# 	Carla will be reporting to McKenzie Largay.
#
# Lawrence Raju: Staff Accountant | Accounting - ISA | Remote
# 	Previously worked as Accounts Payable Specialist I at Honda Performance Development (Contingent Position).
# 	Lawrence will be reporting to Vicky Agalsoff.
#
# Trevor Lewis: Senior Social Strategist | Connections - T3 | Remote
# 	Previously worked as Content Marketing Strategist at Envision Creative.
# 	Trevor Lewis will be reporting to Candice Garcia.
#
# Lugdivine Pironi: Research Director | LRWTonic | London
# 	Previously worked as Client Manager at Kantar.
# 	Lugdivine will be reporting to Tia Best.
#
# Diane Harris: Accounts Payable Specialist | Finance - T3 | Austin
# 	Previously worked as Accounts Payable at JMJ Associates.
# 	Diane will be reporting to Robert Hurley.
#
# Joseph Calinda: Coordinator, Growth Strategy | G&A: Admin - KEL | Los Angeles 1900
# 	Previously worked as Manager, Digital Revelations at Revelations Entertainment.
# 	Joseph will be reporting to Alison Servi.
#
# Kara Sisenstein: Senior Analyst, Quantitative | Client Services: KQS - KEL | New York
# 	Previously worked as Project Associate at Greenberg Quinlan Rosner Research.
# 	Kara will be reporting to Matt Paladino.
#
# Jennifer Schwegler: Recruiter | Group HR | Remote
# 	Previously worked as Recruiting Consultant at AppleOne Employment Services.
# 	Jennifer Schwegler will be reporting to Alex Martin.
#
# Paulo Fong: Personal & Administrative Assistant | SBS Panels and Samples - ISA | Van Nuys
# 	Previously worked as Customer Service Representative at Contractors Wardrobe.
# 	Paulo Fong will be reporting to Jacqueline Rosales.
#
# Patrick Reynolds: Research Manager | TIBU | Remote
# 	Previously worked as Project Manager at Elliott Benson Research.
# 	Patrick will be reporting to Alex Greenfield.
#
# Robert Boggs: Workplace Experience Coordinator | Workplace Experience | Emeryville
# 	Previously worked as Facilities Coordinator at RR Donnelley.
# 	Robert will be reporting to Katie Cole.
#
# Melissa Parkerson: Workplace Experience Coordinator | Workplace Experience | Los Angeles 1900
# 	Previously worked as Sr. Workplace Operations Coordinator at Pivotal Labs.
# 	Melissa will be reporting to Jason Redondo.
#
# John Owens: Research Manager | Cottrell | Los Angeles 1900
# 	Previously worked as Data Analyst at Inner City Struggle.
# 	John will be reporting to Maura LaBrecque.
#
# Laura Rojas: Research Operations Manager | LRWTonic | New York
# 	Previously worked as Project Manager at Transperfect.
# 	Laura will be reporting to Thais Martin.
#
# Hannah O'Keefe: Research Manager | Keever | Remote
# 	Previously worked as Research Associate at Gallagher.
# 	Hannah will be reporting to Julia Garcia.
#
# Rachael DeRoest: Project Success Manager | SBS Panels and Samples - ISA | Remote
# 	Previously worked as Copywriter at Claim Your Shero.
# 	Rachael will be reporting to Tod Mack.
#
# Sydney Rodriguez: Social Coordinator | Connections - T3 | Remote
# 	Previously worked as Marketing Manager at Premiere Surgical Arts.
# 	Sydney will be reporting to Candice Garcia.
#
# Priscyla Isabel Vargas Arzola: Ad Operations Specialist | Connections - T3 | Remote
# 	Previously worked as Programmatic Associate at Just Global.
# 	Priscyla will be reporting to Manoj Thomas.
#
# Liliia Neshcheret: Design Resource Coordinator | Design | Remote
# 	Previously worked as Operations Coordinator at Annuities Genius.
# 	Liliia will be reporting to Marcus Lee.
#
# Anna Choi: Workplace Experience Coordinator | Workplace Experience | Los Angeles 1900
# 	Previously worked as Maintenance Coordinator at Parker Palm Springs.
# 	Anna will be reporting to Jason Redondo.
#
# Sandhya Keshavabhotla: Designer | Design | Remote
# 	Previously worked as Graphic Design Freelancer at nan.
# 	Sandhya will be reporting to Marcus Lee.
#
# Zachary Taylor: Designer | Design | Remote
# 	Previously worked as Creative Director at Ransom Digital.
# 	Zachary will be reporting to John Wuchte.
#
# Izgi Yavuz Tapia: Designer | Design | Los Angeles 1800
# 	Previously worked as Freelance Graphic Designer at nan.
# 	Izgi will be reporting to Marcus Lee.
#
# Kaitlin Shaffer: Research Manager | Li | Los Angeles 1800
# 	Previously worked as Consultant, Product Owner and Director of Market Research at scripsense, Inc.
# 	Kaitlin will be reporting to Apoorva Kelkar.
#
# Lisa Teufel: Workplace Experience Coordinator | Workplace Experience | Austin
# 	Previously worked as President and Marketing Manager at Delight Ministries.
# 	Lisa will be reporting to Kasey Mitchell.
#
# Oliver Tate: Senior Analyst, Quantitative | Kelton | Remote
# 	Previously worked as Business Consultant at CSUN.
# 	Oliver will be reporting to Cameron Gonzalez.
#
# Anna Wilson: Senior Analyst, Quantitative | Kelton | Remote
# 	Previously worked as nan at nan.
# 	Anna will be reporting to TBD.
#
# Davis Porges: Research Associate | Cottrell | Remote
# 	Previously worked as Consumer Insights & Strategy Intern at Traeger Grills.
# 	Davis will be reporting to Agnes Wasilewski.
#
# Chapman Li: Quantitative Analyst | Client Services: KQS - KEL | Los Angeles 1900
# 	Previously worked as Data Science Intern at Zindi.
# 	Chapman will be reporting to Victoria McSweeney.
#
# Ethan Sneider: Quantitative Analyst | Client Services: KQS - KEL | New York
# 	Previously worked as nan at nan.
# 	Ethan will be reporting to Hussain Hakam.
#
# Eric Feliz: Global Data Collection Associate | Global Data Collection | Remote
# 	Previously worked as nan at nan.
# 	Eric will be reporting to TBD.
#
# Cindy Lu: Global Data Collection Associate | Global Data Collection | Remote
# 	Previously worked as Digital Marketing Intern at SC Trojans Athletics.
# 	Cindy will be reporting to Michael Frontino.
#
# Kyle Murphy: Global Data Collection Associate | Global Data Collection | Los Angeles 1900
# 	Previously worked as Campus Director at Fanimal, Inc.
# 	Kyle will be reporting to Alexa Dobrowski.
#
# Elizabeth Weis: Analyst, Qualitative Research | Client Services: Qual - KEL | Remote
# 	Previously worked as Clinical Research Coordinator at Memory & Aging Center (UCSF).
# 	Elizabeth will be reporting to Aviva Urkov.
#
# Raymonde Cook: Senior Research Manager | LRWTonic | London
# 	Previously worked as Senior Project Manager at Ipsos Mori.
# 	Ray will be reporting to Jenn Arrington-Korek.
#
# Mason Miranda: PR Account Executive | Employees - KAR | Remote
# 	Previously worked as Credit Industry Specialist at Credit Card Insider.
# 	Mason will be reporting to Cat McQuail.
#
# Kelsey Parker-Montagnini: Research Associate | Jagou | Remote
# 	Previously worked as Phone Banker at Planned Parenthood.
# 	Kelsey will be reporting to Renata Filler.
#
# Isobel Riant: Research Associate | Cottrell | New York
# 	Previously worked as Beauty Advisor at Sephora.
# 	Isobel will be reporting to Alex Cervantes.
#
# Tim Conley: Recruiting Coordinator | Group HR | Los Angeles 1900
# 	Previously worked as Operations & HR Assistant at Zuber Lawler LLP.
# 	Tim Conley will be reporting to Anna Berk.
#
# Tabitha Hoover: Communications Coordinator | T3 | Remote
# 	Previously worked as Digital Media Specialist at Digital Media Specialist.
# 	Tabitha will be reporting to Emma Coker.
#
# Ali Husain: Research Associate | Li | Los Angeles 1900
# 	Previously worked as Associate at Welch Consulting.
# 	Ali will be reporting to Apoorva Kelkar.
#
# Andrea Escobar Vara: Research Associate | Klubis | Los Angeles 1900
# 	Previously worked as Customer Relationship Management Specialist at Center for Customer Insights and Digital Marketing.
# 	Andrea will be reporting to Carlos Zambrano.
#
# Rachel Moreh: Research Associate | LRWTonic | Los Angeles 1900
# 	Previously worked as Director of Specialized Public Diplomacy at Consulate General of Israel.
# 	Rachel will be reporting to Nathan Vincent.
#
# Jiali Wu: Research Associate | TIBU | Remote
# 	Previously worked as Research Assistant at Computational Vision and Learning Lab.
# 	Jolie will be reporting to Ben Abrams.
#
# Yeraimyz Saavedra: Designer | LRWTonic | New York
# 	Previously worked as Freelance Designer at nan.
# 	Yeraimyz will be reporting to Seyi Matthews.
#
# Katie Lee: Associate Survey Engineer | IPS | Remote
# 	Previously worked as Dental Receptionist at Wedgwood Family Dentistry.
# 	Katie will be reporting to Kayla Elias.
#
# Stephanie Burton: Research Associate | Stone | Chicago
# 	Previously worked as Brokerage Associate Lead at NinjaTrader Brokerage, LLC.
# 	Stephanie will be reporting to Allison Lee.
#
# Emilie Fleck: Research Associate | TIBU | Los Angeles 1800
# 	Previously worked as Retail Associate at HomeGoods.
# 	Emilie will be reporting to Venessa Scott.
#
# Shay Santos: Research Associate | TIBU | Los Angeles 1800
# 	Previously worked as Front Desk Operations & Social Media Representative at The Bar Method Fresno.
# 	Shay will be reporting to Natalie Montes.
#
# Matt Milburn: Research Associate | Valenzuela | Los Angeles 1900
# 	Previously worked as Marketing Intern at Getinthekitchen (Loyola University Chicago).
# 	Matt will be reporting to TBD.
#
# Tanya Reynolds: Research Associate | TIBU | Remote
# 	Previously worked as Consumer Research & Insights Manager at Bodybuilding.com.
# 	Tanya will be reporting to Liam O'Connell.
#
# Khoreen Eason: Recruiting Coordinator | Group HR | Remote
# 	Previously worked as Talent Acquisition Coordinator at GoHealth Urgent Care.
# 	Khoreen Eason will be reporting to Alex Martin.
#
# Devon Else: Assistant Account Executive | Employees - KAR | Philadelphia
# 	Previously worked as Community Supporters Intern at Leukaemia Foundation.
# 	Devon will be reporting to Kyle McDonough.
#
# Marielle Geerling: Assistant Account Executive | Employees - KAR | Remote
# 	Previously worked as Administrative Assistant at General Healthcare Resources, Inc.
# 	Marielle will be reporting to Heather Dougherty.
#
# Elizabeth Betchart: Research Associate | Jagou | Los Angeles 1900
# 	Previously worked as Supervisor at Pizza My Heart.
# 	Elizabeth will be reporting to Paul Bergevin.
