# %% [markdown]
# <a href="https://colab.research.google.com/github/leokim-material/report-new_hires/blob/main/report_new_hires.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Print list of new hires in following format:
# Name: Title | Company | Location
# Previously worked as TITLE at COMPANY. 
# PREFERRED NAME will be reporting to MANAGER.

from google.colab import files
import pandas as pd
import os
from termcolor import colored #format font color
import numpy as np

# %%
#Setup files
time_period = '2021-Q4'
directory = 'drive/MyDrive/Colab Notebooks/report-new hires/data/' + time_period

#Read files
df_offer_details = pd.read_excel(directory + '/' + 'offer_details_10.xlsx', header=3)
df_candidates = pd.read_excel(directory + '/' + 'candidates_10.xlsx')
#Add column for first+last name
df_candidates['Candidate'] = df_candidates['First Name'] + ' ' + df_candidates['Last Name']

#Merge (default inner=intersection)
#List of columns to keep
keep_columns = ['Candidate', 'Job', 'Preferred Name', 'Location_x', 'Department.1', 'Manager', 'Employment Type', 
                'Rate Type', 'Pay Rate', 'Title', 'Company', 'Location_y', 'Education1']
df_hired = df_offer_details.merge(df_candidates, on='Candidate')#[keep_columns]

#Clean up------------------------------------------------------

#Filter for FTE
df_hired = df_hired.loc[df_hired['Employment Type'] == 'Full-time'].reset_index(drop=True)

#Pay Rate: remove currency symbols & convert hourly rate to annualized salary
df_hired['Pay Rate'] = df_hired['Pay Rate'].str.replace('[$€,]', '').astype('float')
print('Pay Rate dtype correctly converted?', df_hired['Pay Rate'].dtypes)
#np.where(condition, result if condition met, result if not met)
df_hired['Pay Rate'] = np.where(df_hired['Rate Type'] == 'Hourly- Full Time', df_hired['Pay Rate'] * 2080, df_hired['Pay Rate'])
df_hired = df_hired.sort_values(['Pay Rate', 'Job'], ascending=False).reset_index(drop=True)
#---------------------------------------------------------------

#Check repeat names
df_hired['Candidate'].value_counts()[df_hired['Candidate'].value_counts() > 1]
# Out:
# Pay Rate dtype correctly converted? float64
# Series([], Name: Candidate, dtype: int64)

# %%
#notes
#Eric Feliz - manager=Kayla Takemoto
#Received an M.S. in Management from University of Notre Dame

#Sandhya Keshavabhotla - prev worked through Upwork
#Lee Saunders - rehired
#Anna Wilson - Received a BSBA with emphasis in Marketing from University of Colorado
#Anna will be reporting to Laura Majonnier.

#Izgi Yavuz Tapia - freelancer no comapny
#Raymonde Cook - freelancer FOR Blux
#change all senior to Sr. for job title & prev job title
#
#hohjin im - received phd

#AUGUST
#remove 'material newhireone two'

#SEPTEMBER
#checked 9/1-9/19

# %%
#Number of new hires
count = df_hired.shape[0]
print(str(count) + ' FTE', '\n')

for candidate in range(df_hired.shape[0]):
  #Grab variables
  full_name = '\033[1m' + df_hired.loc[candidate, 'Candidate'] + '\033[0m'
  job_title = df_hired.loc[candidate, 'Job']
  department = '\x1B[3m' + str(df_hired.loc[candidate, 'Department.1']) + '\x1B[0m'
  location = '\x1B[3m' + df_hired.loc[candidate, 'Location_x'] + '\x1B[0m'
  prev_job_title = str(df_hired.loc[candidate,'Title'])
  prev_company = colored(df_hired.loc[candidate,'Company'], 'blue')
  nickname = df_hired.loc[candidate,'Preferred Name']
  manager = df_hired.loc[candidate,'Manager']

  print(full_name + ': ' + job_title + ' | ' + department + ' | ' + location
        + '\n\tPreviously worked as ' + prev_job_title + ' at ' + prev_company + '.'  
        + '\n\t' + nickname + ' will be reporting to ' + manager + '.'
        + '\n'
        )
# Out:
# 46 FTE
#
# Neil Brown: Managing Director, Product Design | Product Design - T3 | Remote
# 	Previously worked as Managing Director at Humanaut.
# 	Neil Brown will be reporting to Caroline Kennedy.
#
# Scott Erwin: Enterprise Architect, Business Applications | Group IT - Business Applications | Remote
# 	Previously worked as Business Technology Manager at California Water Service.
# 	Scott will be reporting to Wael Amer.
#
# Ben Hillson: Director of Design Research | Product Design - T3 | Austin
# 	Previously worked as Global Design Lead at IBM.
# 	Ben will be reporting to Ricardo Salema.
#
# Aline Bakchajian: Engagement Lead | Group Connections | Los Angeles 1900
# 	Previously worked as Research Director at Fuel Cycle.
# 	Aline will be reporting to Taylor Hight.
#
# Shohag Dey: Research Director | Li | Remote
# 	Previously worked as Director at YouGov.
# 	Shohag will be reporting to TBD.
#
# Robert Schwartz: Director, Strategy | Strategy & Innovation - T3 | Remote
# 	Previously worked as Strategist Consultant at Hero Digital.
# 	Robert Schwartz will be reporting to Keith Tanski.
#
# Amy Johnson: Research Director | Keever | Remote
# 	Previously worked as Director at Ipsos.
# 	Amy will be reporting to TBD.
#
# Kim Bozick: Group Account Director | Account Management - T3 | Remote
# 	Previously worked as Account Supervisor at Social Factor.
# 	Kim will be reporting to Lindsey Mongrain.
#
# Harrison May: Director, Strategy | Element Y - GB | Remote
# 	Previously worked as Director Of Operations at Cascade Insights.
# 	Harrison will be reporting to Margaret Cody Nagarajan.
#
# Kelsey Vanhee: Senior Associate for Diversity, Equity, and Inclusion | Group - Diversity, Equity, & Inclusion | Remote
# 	Previously worked as Senior Program Coordinator at Bill & Melinda Gates Foundation.
# 	Kelsey will be reporting to Kiva Wilson.
#
# Avi Rabin: Data Engineer | Marketing Science | Los Angeles 1900
# 	Previously worked as Data Engineer at Capgemini.
# 	Avi will be reporting to Hrag Balian.
#
# Richard Meneses: Application Administrator, Finance | Group IT - Business Applications | Remote
# 	Previously worked as Application Administrator - Financial Systems at Radian Group Inc.
# 	Richard will be reporting to Adam Herrera.
#
# Tracy Lakes: Application Administrator, Talent | Group IT - Business Applications | Remote
# 	Previously worked as HRIS Functional Analyst at Florida State College.
# 	Tracy will be reporting to Shontel Gray.
#
# Diana Padron de la Torre: Senior Product Designer | T3 | Remote
# 	Previously worked as Senior Visual Designer at 10up.
# 	Diana will be reporting to Ricardo Salema.
#
# Beatriz Barron: Senior Associate for Diversity, Equity, and Inclusion | Group - Diversity, Equity, & Inclusion | Remote
# 	Previously worked as Diversity Programs and Operations Coordinator at Cross-Cultural Center.
# 	Beatriz will be reporting to Kiva Wilson.
#
# Erin Breen: Senior Research Manager | Cottrell | Remote
# 	Previously worked as Senior Researcher at MullenLowe.
# 	Erin will be reporting to Madeleine Chansky.
#
# Toheeb Alejo: Senior Analyst, Customer Data Analytics | Marketing Science | Remote
# 	Previously worked as Data Analyst at Hitachi.
# 	Toheeb will be reporting to Rosy Garcia-Rivas.
#
# Casey Colesworthy: Supervisor, PR & Communications | Employees - KAR | Remote
# 	Previously worked as Marketing Director at The Hoyte Group.
# 	Casey Colesworthy will be reporting to Tiffany Francis.
#
# Tiondrae Pier: Manager, Brand Strategy | Client Services: Qual - KEL | Remote
# 	Previously worked as Strategy & Consulting Analyst at Accenture.
# 	Tiondrae will be reporting to Jay Becton.
#
# Cheyenne Love: Consultant, CX Consulting | Strativity | Remote
# 	Previously worked as Business Process Analyst at CGI Inc.
# 	Cheyenne Love will be reporting to Pernell Cox.
#
# Laura Lucio: Project Manager | CX | Remote
# 	Previously worked as Project Manager at Samaritan Ministries International.
# 	Laura will be reporting to Jia Fong.
#
# Oscar Ojeda: Motion Graphics Designer | Creative - T3 | Remote
# 	Previously worked as Freelance Motion Graphic Artist at Squadron TV.
# 	Oscar will be reporting to Caleb Sawyer.
#
# Esti O'Connell: Manager, Experience Research | Client Services: KQS - KEL | Remote
# 	Previously worked as Consumer Insight & Trend Analyst at Ziba Design.
# 	Esti will be reporting to Lisa Boumstein-Smalley.
#
# Djenaldbeth Louis: Manager, Brand Strategy | Qual Insights | Remote
# 	Previously worked as Strategic Planner at Ten35.
# 	Djenaldbeth will be reporting to Jay Becton.
#
# Meher Shahabadi: Recruiter | Group HR | Remote
# 	Previously worked as Talent Acquisition Specialist at TASKids.
# 	Meher will be reporting to Alex Martin.
#
# Huy Nguyen-Quoc: Data Engineer | IPS | Remote
# 	Previously worked as Data Analyst  at Melissa Data.
# 	Huy will be reporting to Christopher Valenzuela.
#
# Cara Christensen: Director of Growth, Insights & Research | Manager, Account Services - ISA | Remote
# 	Previously worked as VP Client Services at I/H/R Research and Restaurant Research & Associates.
# 	Cara will be reporting to Adriana Hemans.
#
# Abby Deffler: Project Manager | LRWTonic | New York
# 	Previously worked as Field and Project Manager at Shapiro+RAJ.
# 	Abby will be reporting to Allison Zack.
#
# Ashlyn Watkins: Senior Account Executive | Employees - KAR | Remote
# 	Previously worked as PR & Marketing Manager at Alabama Ballet.
# 	Ashlyn will be reporting to Patrick Reiher.
#
# Abby Hyland: Research Manager | TIBU | Los Angeles 1800
# 	Previously worked as Programs Manager at Center for Student Wellness & Health Promotion.
# 	Abby will be reporting to TBD.
#
# Alyssa Kathryn Edmond: Research Associate | Steging | New York
# 	Previously worked as Self-Paced Program Advisor at Girls Who Code.
# 	Alyssa Edmond will be reporting to James DeSimas.
#
# Sarah Almagsoosi: Global Data Collection Associate | Global Data Collection | Remote
# 	Previously worked as Student Counselor at Cypress Community College.
# 	Sarah will be reporting to Julia Gouzikovski.
#
# Haley Adams: Research Associate | Cottrell | Los Angeles 1900
# 	Previously worked as Geospatial Analyst at Maxar Technologies.
# 	Haley will be reporting to Agnes Wasilewski.
#
# Kira Marion Gresser: Research Associate | LRWTonic | Remote
# 	Previously worked as Resort Hostess at Gurney's Montauk.
# 	Kira will be reporting to Molly Young.
#
# Jad Monzer Nachabe: Research Associate | Cottrell | Los Angeles 1900
# 	Previously worked as Undergraduate Research Team Lead at Cal Poly.
# 	Jad will be reporting to Charlie Rosenblum.
#
# Samantha Hyer: Research Associate | TIBU | Remote
# 	Previously worked as Jungle Cruise Attractions Host at Disneyland Resort.
# 	Samantha will be reporting to Natalie Montes.
#
# Chan Kim: Research Associate | TIBU | Remote
# 	Previously worked as Mathematics Instructor at Genesis Academy.
# 	Chan will be reporting to Jennifer Rohr.
#
# Erin Babamoto: Research Associate | TIBU | Los Angeles 1800
# 	Previously worked as Accountant at Gas Media Group LLC.
# 	Erin will be reporting to Troy Fleiner.
#
# Sabina Marie Di Padua: Research Associate | Jagou | Los Angeles 1900
# 	Previously worked as Supplemental Instruction Leader at Teaching and Learning Commons.
# 	Sabina will be reporting to Jason Parnass.
#
# Cayleigh Kelly: Research Associate | Jagou | Remote
# 	Previously worked as Regional Outreach VISTA member at PAARI Recovery Corps.
# 	Cayleigh will be reporting to TBD.
#
# Kasey Kim: Research Associate | Jagou | Los Angeles 1900
# 	Previously worked as Global Youth Advocate Intern at Humanitarian Affairs Asia.
# 	Kasey will be reporting to Melissa Kerley.
#
# Katrina Williams: Research Associate | Valenzuela | Los Angeles 1900
# 	Previously worked as Strategy Intern at BBDO LA.
# 	Katrina will be reporting to Caroline Hisey.
#
# Emma Liu: Research Associate | Shrut | Remote
# 	Previously worked as Mathematics Teacher at Jones International Christian School.
# 	Emma will be reporting to Mira Metry.
#
# Michelle Gonzaba: Market Research Associate | SBS Panels and Samples - ISA | Remote
# 	Previously worked as Columnist & Forum Moderator at BioNews Services.
# 	Michelle will be reporting to Julie McClammy.
#
# Shawn Michael Nicholson: Research Associate | Steging | Remote
# 	Previously worked as Embedded Tutor at Center for Student Success.
# 	Shawn will be reporting to TBD.
#
# Nicholas Strickland: Online Customer Support - Entry Level | SBS Panels and Samples - ISA | Remote
# 	Previously worked as Project Assistant & File Manager at Exact Staff.
# 	Nick will be reporting to Cynthia Ramos.
